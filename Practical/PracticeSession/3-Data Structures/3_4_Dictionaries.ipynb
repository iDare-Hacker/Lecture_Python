# %% [markdown]
# #### Dictionaries
# Outline:
# 1. Introduction to Dictionaries
# 2. Creating Dictionaries
# 3. Accessing Dictionary Elements
# 4. Modifying Dictionary Elements
# 5. Dictionary Methods
# 6. Iterating Over Dictionaries
# 7. Nested Dictionaries
# 8. Dictionary Comprehensions
# 9. Practical Examples and Common Errors

# %% [markdown]
# ##### Introduction to Dictionaries
#
# Dictionaries are unordered collections of items. They store data in key-value pairs.
# Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any type.

# %%
## Creating Dictionaries
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student={"name":"Tirup","age":32,"grade":24}
print(student)
print(type(student))
# Out:
# {'name': 'Tirup', 'age': 32, 'grade': 24}
# <class 'dict'>

# %%
# Single key is slways used
student={"name":"Tirup","age":32,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 32}

# %%
## accessing Dictionary Elements
student={"name":"Tirup","age":32,"grade":'A'}
print(student)
# Out:
# {'name': 'Tirup', 'age': 32, 'grade': 'A'}

# %%
## Accessing Dictionary elements
print(student['grade'])
print(student['age'])

## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not Available"))
# Out:
# A
# 32
# A
# None
# Not Available

# %%
## Modifying Dicitonary Elements
## Dictionary are mutable,so you can add, update or delete elements
print(student)
# Out:
# {'name': 'Tirup', 'age': 32, 'grade': 'A'}

# %%
student["age"]=33  ##update value for the key
print(student)
student["address"]="India" ## added a new key and value
print(student)
# Out:
# {'name': 'Tirup', 'age': 33, 'grade': 'A'}
# {'name': 'Tirup', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade'] ## delete key and value pair

print(student)
# Out:
# {'name': 'Tirup', 'age': 33, 'address': 'India'}

# %%
## Dictionary methods

keys=student.keys() ##get all the keys
print(keys)
values=student.values() ##get all values
print(values)

items=student.items() ##get all key value pairs
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Tirup', 33, 'India'])
# dict_items([('name', 'Tirup'), ('age', 33), ('address', 'India')])

# %%
## shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Tirup', 'age': 33, 'address': 'India'}
# {'name': 'Tirup', 'age': 33, 'address': 'India'}

# %%
student["name"]="Tirup2"
print(student)
print(student_copy)
# Out:
# {'name': 'Tirup2', 'age': 33, 'address': 'India'}
# {'name': 'Tirup2', 'age': 33, 'address': 'India'}

# %%
student_copy1=student.copy() ## shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Tirup2', 'age': 33, 'address': 'India'}
# {'name': 'Tirup2', 'age': 33, 'address': 'India'}

# %%
student["name"]="Tirup3"
print(student_copy1)
print(student)
# Out:
# {'name': 'Tirup2', 'age': 33, 'address': 'India'}
# {'name': 'Tirup3', 'age': 33, 'address': 'India'}

# %%
### Iterating Over Dictionaries
## You can use loops to iterate over dictionatries, keys,values,or items

## Iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
## Iterate over values
for value in student.values():
    print(value)
# Out:
# Tirup3
# 33
# India

# %%
## Iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Tirup3
# age:33
# address:India

# %%
## Nested Disctionaries
students={
    "student1":{"name":"Tirup","age":32},
    "student2":{"name":"Rushaank","age":35}
}
print(students)
# Out:
# {'student1': {'name': 'Tirup', 'age': 32}, 'student2': {'name': 'Rushaank', 'age': 35}}

# %%
## Access nested dictionaries elementss
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Rushaank
# 35

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Tirup', 'age': 32}), ('student2', {'name': 'Rushaank', 'age': 35})])

# %%
## Iterating over nested dictionaries
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Tirup', 'age': 32}
# name:Tirup
# age:32
# student2:{'name': 'Rushaank', 'age': 35}
# name:Rushaank
# age:35

# %%
## Dictionary Comphrehension
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Condition dictionary comprehension
evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical Examples

## USe a dictionary to count he frequency of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge 2 dictionaries into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# #### Conclusion
# Dictionaries are powerful tools in Python for managing key-value pairs. They are used in a variety of real-world scenarios, such as counting word frequency, grouping data, storing configuration settings, managing phonebooks, tracking inventory, and caching results. Understanding how to leverage dictionaries effectively can greatly enhance the efficiency and readability of your code.
